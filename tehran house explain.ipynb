# %% [markdown]
# # result of campare based on Area

# %%
""""
The plots in this section are analyzed based on area:

Rooms:
•	For areas above 600 m², the number of rooms is actually zero.
•	For areas between 300 and 450 m², we observe the distribution of rooms.
•	Most of the double rooms are related to areas between 90 and 150 m².

Parking:
•	For areas between 150 and 450 m², the distribution of parking spaces is observed.
•	The highest number of parking spaces belongs to areas below 150 m².
•	For areas above 450 m², we have the lowest number, mainly because such areas are the least frequent in the dataset.

warehouse:
•	The storage distribution is almost similar to parking.

Elevator:
•	The number of elevators is the highest for areas between 150 and 300 m².

Price:
•	The highest price is for areas around 300 m², followed by areas between 60 and 150 m².

Price (USD):
•	The highest frequency in the price range around 1 (unit) corresponds to 300 m².
•	For the range between 0 and close to 1, the corresponding area is around 100 m².
"""

# %% [markdown]
# # result of campare based on Room

# %%
"""
Comparison based on the number of rooms:

Area:
- For 4–5 rooms in sizes between 500–1000 m² and above 1000 m², the count is almost zero.
- For areas between 0–500 m², the highest number of rooms belongs respectively to 2-room, 1-room, and 3-room houses.

Parking:
- The highest number of single parking spaces belongs to 2-room houses, followed by 3-room houses.
- For 5-room houses, almost no parking spaces are defined (value = 0).

Warehouse:
- A single warehouse corresponds mostly to 1-room houses, followed by 3-room houses.
- After that, it again relates to 1-room houses.
- For 5-room houses, there is almost no distribution regarding warehouses.

Elevator:
- The condition is similar to warehouses.

Price:
- Single-room houses and houses without any rooms appear mostly in the lower price ranges of the chart.
- Houses with higher prices have been purchased less frequently.

Price (USD):
- The condition is similar to price.

Address:
- In the region 100–200, most houses have 1 room.
- Overall, in the entire address dataset, 1-room houses have the highest count.
- Next are houses with 2 bedrooms.
"""

# %% [markdown]
# # result of campare based on Parking

# %%
"""
Comparison based on parking:

Area:
- Houses with areas in the 0–500 m² range mostly have parking spaces.
- For areas above 500 m², almost no distribution for elevators is defined.

Rooms:
- The highest number of rooms for houses with parking is 2, followed by 3 rooms.
- In fact, parking exists in all room ranges.
- The number of houses with parking is higher than those without parking in all ranges.

Warehouse:
- In this chart, the distribution indicates that every house with parking also has a warehouse, and every house without parking has no warehouse.
- There are a few exceptions, but the reverse cases are very few.

Elevator:
- Similar to the warehouse situation.

Price:
- In the range up to 0.5, there is almost parking, but the steepest increase occurs around 0.2.
- Of course, in this range, houses without elevators also exist, and their number is less compared to those with elevators.

Price (USD):
- The situation is similar to price.

Address:
- There is almost a bimodal distribution of houses: in the region 100–200, the number of houses with parking is higher than without parking; in the range 0–100, houses with parking are also more than those without.
"""

# %% [markdown]
# # result of campare based on elevator

# %%
"""
Comparison based on elevator:

Area:
- Houses with areas in the 0–500 m² range mostly have elevators.
- For areas above 500 m², almost no distribution for elevators is defined.

Rooms:
- The highest number of rooms for houses with elevators is 2, followed by 3 rooms.
- In fact, elevators exist in all room ranges.
- The number of houses with elevators is higher than those without elevators in all ranges.

Warehouse:
- In this chart, the distribution indicates that every house with an elevator also has a warehouse, and every house without an elevator has no warehouse.
- There are a few exceptions, but the reverse cases are very few.

Elevator:
- Similar to the warehouse situation.

Price:
- In the range up to 1,2 there is almost an elevator, but the steepest increase occurs around 0.2.
- Of course, in this range, houses without elevators also exist, and their number is less compared to those with elevators.

Price (USD):
- The situation is similar to price.

Address:
- There is almost a bimodal distribution of houses: in the region 100–200, the number of houses with elevators is higher than without elevators; in the range 0–100, houses with elevators are also more than those without.
"""

# %% [markdown]
# # result of campare based on Warehouse

# %%
"""
Comparison based on warehouse:

Area:
- Houses with areas in the 0–500 m² range mostly have warehouses.
- For areas above 500 m², almost no distribution for warehouses is defined.

Rooms:
- The highest number of rooms for houses with warehouses is 2, followed by 3 rooms.
- In fact, warehouses exist in all room ranges.
- The number of houses with warehouses is higher than those without warehouses in all ranges.

Warehouse:
- In this chart, the distribution indicates that every house with a warehouse also has a warehouse, and every house without a warehouse has no warehouse.
- There are a few exceptions, but the reverse cases are very few.

Elevator:
- Similar to the warehouse situation.

Price:
- In the range up to 1,2 there is almost a warehouse, but the steepest increase occurs around 0.2.
- Of course, in this range, houses without warehouses also exist, and their number is less compared to those with warehouses.

Price (USD):
- The situation is similar to price.

Address:
- There is almost a bimodal distribution of houses: in the region 100–200, the number of houses with warehouses is higher than without warehouses; in the range 0–100, houses with warehouses are also more than those without.
"""

# %% [markdown]
# # result of campare based on Price

# %%
"""
Comparison based on price:

Area:
- As the area increases, the price tends to be higher.
- Around 100 m², most houses are purchased at a price of 200 million.
- As the area increases up to 500 m², the most common prices are 400 million and then 600 million.

Rooms:
- The highest number of rooms for the 200 million price range is 1–2 rooms.
- For houses in the 400 million price range, the most common number of rooms is 3.

Parking:
- For all price ranges, most houses have parking.
- However, in the 200 million price range, there are also houses without parking, but the majority have parking.

Warehouse:
- Similar to the parking situation.

Elevator:
- Similar to the parking and warehouse situation.

Price (USD):
- The highest frequency corresponds to the 200 million price range.

Address:
- In the regions 0–200, the highest number of houses belongs to the 200 million price range, which is the most frequent overall.
"""

# %% [markdown]
# # result of campare based on Address

# %%
"""
Comparison based on address:

Area:
- In the area range 0–500 m², the highest number of houses belongs to regions 160 and 120.
- The lowest number of houses corresponds to regions 0 and 40.

Rooms:
- In region 160, single-room houses are the most frequent.
- Two-room houses are most common in region 120.
- Three-room houses are most frequent in region 0.

Parking:
- Region 80 has the highest number of houses with parking.
- Overall, the highest number of houses with parking belongs to regions 40 and 80.

Warehouse:
- Similar to the parking situation.

Elevator:
- Similar to parking and warehouse.

Price:
- In the range 0–1, the highest number of houses belongs to region 120.

Price (USD):
- Similar to the above case.
"""
